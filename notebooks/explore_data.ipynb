# %%
import pandas as pd
from desdeo_problem.problem import DiscreteDataProblem

df = pd.read_csv("../data/DTLZ2_5x_3f.csv")

# %%
import numpy as np

pareto_f = df.to_numpy()

ideal = np.min(pareto_f[:, 0:3], axis=0)
nadir = np.max(pareto_f[:, 0:3], axis=0)

# %%
problem = DiscreteDataProblem(df, ["x1", "x2", "x3", "x4", "x5"], ["f1", "f2", "f3"], nadir, ideal)

# %%
from mpl_toolkits import mplot3d
# %matplotlib notebook
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection="3d")

objectives = problem.objectives[:, 0:3]

ax.scatter3D(objectives[:, 0], objectives[:, 1], objectives[:, 2], "blue")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.hstack(tuple(np.random.uniform(low=ideal[i], high=nadir[i], size=(100,1)) for i in range(ideal.shape[0])))
# Out:
# array([[0.20430251, 0.2916685 , 0.26583245],
#        [0.62112725, 0.79648745, 0.99178806],
#        [0.184918  , 0.31608624, 0.99147624],
#        [0.7957453 , 0.74044918, 0.34771675],
#        [0.51712462, 0.19141749, 0.3158503 ],
#        [0.42000888, 0.30784255, 0.12376028],
#        [0.4136044 , 0.65414506, 0.9352927 ],
#        [0.89708321, 0.48486885, 0.13324715],
#        [0.97081144, 0.30880839, 0.78335195],
#        [0.89902605, 0.61602343, 0.64129779],
#        [0.02066449, 0.04233242, 0.80289666],
#        [0.63258377, 0.86220799, 0.61177687],
#        [0.25869082, 0.21817181, 0.21373178],
#        [0.9649975 , 0.63602537, 0.26917455],
#        [0.9830006 , 0.41894366, 0.03322497],
#        [0.98499528, 0.27660513, 0.98758544],
#        [0.45634134, 0.65482427, 0.64291906],
#        [0.00362887, 0.14459311, 0.40663995],
#        [0.76806101, 0.44637996, 0.44940135],
#        [0.86133851, 0.73869432, 0.28449635],
#        [0.76804511, 0.12296933, 0.29309255],
# ...
